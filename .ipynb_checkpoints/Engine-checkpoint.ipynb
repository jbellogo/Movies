# %%
import pandas as pd
import requests
import json

pd.options.display.max_columns = 30

# %%
def page_url(page=1):
    '''
    Uses default query specifications
    '''
    api_key  = "api_key=d2ba87d601823962c8cc04aa877278a1"
    discover_api = "https://api.themoviedb.org/3/discover/movie?"
    query = "&language=en-US&sort_by=popularity.desc&include_adult=false&page={}&vote_count.gte=500".format(page)
    url = discover_api + api_key + query
    return url

# %%
url = discover_api + api_key + default_query

def make_big_dataframe(max_pages):
    '''
    The API proides data in pages of 10 movies per url request. 
    This function iterates over each page adding the data to one big pandas df
    '''
    if (max_pages >= 214):
        print("max is 213")
        return
    
    frames = []
    
    for page_num in range(1,max_pages+1):
        url = page_url(page_num)
        r = requests.get(url)
        if r.status_code != 200:
            '''Something went wrong'''
            print("Error")
            return
        data = r.json()
        page_df = pd.json_normalize(data = data, record_path = "results") # normalize, as you convert to df
        frames.append(page_df)
       
    # concat dfs into one
    df = pd.concat(frames) # method takes array of df
    
    # process
    df = df.reset_index() # (else they restart at 19)
    df =df[["title",
            "genre_ids",
            "release_date",
            "overview",
            "popularity",
            "vote_count",
            "poster_path",
            "vote_average"]]
    
    return df  

test_frame = make_big_dataframe(10)
# functional

# %%
df = test_frame
df
# Out:
#                              title             genre_ids release_date  \
# 0                         Ad Astra             [18, 878]   2019-09-17
# 1               Sonic the Hedgehog  [28, 35, 878, 10751]   2020-02-12
# 2                         Parasite          [35, 18, 53]   2019-05-30
# 3           Avengers: Infinity War         [28, 12, 878]   2018-04-25
# 4                The Invisible Man         [27, 878, 53]   2020-02-26
# ..                             ...                   ...          ...
# 195                           Thor          [28, 12, 14]   2011-04-21
# 196                Alien: Covenant             [27, 878]   2017-05-09
# 197                       The Mask   [35, 80, 14, 10749]   1994-07-29
# 198  Mission: Impossible - Fallout              [28, 12]   2018-07-13
# 199          2001: A Space Odyssey       [878, 9648, 12]   1968-04-09
#
#                                               overview  popularity  \
# 0    The near future, a time when both hope and har...     165.765
# 1    Based on the global blockbuster videogame fran...     117.793
# 2    All unemployed, Ki-taek's family takes peculia...      96.606
# 3    As the Avengers and their allies have continue...      82.688
# 4    When Cecilia's abusive ex takes his own life a...      94.348
# ..                                                 ...         ...
# 195  Against his father Odin's will, The Mighty Tho...      27.471
# 196  Bound for a remote planet on the far side of t...      25.225
# 197  When timid bank clerk Stanley Ipkiss discovers...      34.309
# 198  When an IMF mission ends badly, the world is f...      32.475
# 199  Humanity finds a mysterious object buried bene...      28.199
#
#      vote_count                       poster_path  vote_average
# 0          3802  /xBHvZcjRiWyobQ9kxBhO6B2dtRI.jpg           6.1
# 1          4784  /aQvJ5WPzZgYVDrxLX4R6cLJCEaQ.jpg           7.5
# 2          8123  /7IiTTgloJzvGI1TAYymCfbfl3vT.jpg           8.5
# 3         18663  /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg           8.3
# 4          2225  /5EufsDwXdY2CVttYOk2WtYhgKpa.jpg           7.2
# ..          ...                               ...           ...
# 195       15015  /prSfAi1xGrhLQNxVSUFh61xQ4Qy.jpg           6.7
# 196        5795  /zecMELPbU5YMQpC81Z8ImaaXuf9.jpg           5.9
# 197        6684  /yd3wjLLeQHJ3oRDy4wwiNNFVyLW.jpg           6.9
# 198        5100  /AkJQpZp9WoNdj7pLYSj1L0RcMMN.jpg           7.3
# 199        7359  /zmmYdPa8Lxx999Af9vnVP4XQ1V6.jpg           8.1
#
# [200 rows x 8 columns]

# %% [markdown]
# ### Now the ML processing starts

# %%
 ## add a column with the concatenation of TITLE and OVERVIEW

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
FEATURES = ["title", "overview"]

def combine_features(row):
    combined_str = ""
    for feat in FEATURES:
        combined_str += row[feat] + " "
    return combined_str


# at a global level (to add the combined features)
# apply is like map for each row
df["combined_features"] = df.apply(combine_features,axis=1) #applying combined_features() method over each rows of dataframe and storing the combined string in "combined_features" column

# %%
df
# Out:
#                              title             genre_ids release_date  \
# 0                         Ad Astra             [18, 878]   2019-09-17
# 1               Sonic the Hedgehog  [28, 35, 878, 10751]   2020-02-12
# 2                         Parasite          [35, 18, 53]   2019-05-30
# 3           Avengers: Infinity War         [28, 12, 878]   2018-04-25
# 4                The Invisible Man         [27, 878, 53]   2020-02-26
# ..                             ...                   ...          ...
# 195                           Thor          [28, 12, 14]   2011-04-21
# 196                Alien: Covenant             [27, 878]   2017-05-09
# 197                       The Mask   [35, 80, 14, 10749]   1994-07-29
# 198  Mission: Impossible - Fallout              [28, 12]   2018-07-13
# 199          2001: A Space Odyssey       [878, 9648, 12]   1968-04-09
#
#                                               overview  popularity  \
# 0    The near future, a time when both hope and har...     165.765
# 1    Based on the global blockbuster videogame fran...     117.793
# 2    All unemployed, Ki-taek's family takes peculia...      96.606
# 3    As the Avengers and their allies have continue...      82.688
# 4    When Cecilia's abusive ex takes his own life a...      94.348
# ..                                                 ...         ...
# 195  Against his father Odin's will, The Mighty Tho...      27.471
# 196  Bound for a remote planet on the far side of t...      25.225
# 197  When timid bank clerk Stanley Ipkiss discovers...      34.309
# 198  When an IMF mission ends badly, the world is f...      32.475
# 199  Humanity finds a mysterious object buried bene...      28.199
#
#      vote_count                       poster_path  vote_average  \
# 0          3802  /xBHvZcjRiWyobQ9kxBhO6B2dtRI.jpg           6.1
# 1          4784  /aQvJ5WPzZgYVDrxLX4R6cLJCEaQ.jpg           7.5
# 2          8123  /7IiTTgloJzvGI1TAYymCfbfl3vT.jpg           8.5
# 3         18663  /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg           8.3
# 4          2225  /5EufsDwXdY2CVttYOk2WtYhgKpa.jpg           7.2
# ..          ...                               ...           ...
# 195       15015  /prSfAi1xGrhLQNxVSUFh61xQ4Qy.jpg           6.7
# 196        5795  /zecMELPbU5YMQpC81Z8ImaaXuf9.jpg           5.9
# 197        6684  /yd3wjLLeQHJ3oRDy4wwiNNFVyLW.jpg           6.9
# 198        5100  /AkJQpZp9WoNdj7pLYSj1L0RcMMN.jpg           7.3
# 199        7359  /zmmYdPa8Lxx999Af9vnVP4XQ1V6.jpg           8.1
#
#                                      combined_features
# 0    Ad Astra The near future, a time when both hop...
# 1    Sonic the Hedgehog Based on the global blockbu...
# 2    Parasite All unemployed, Ki-taek's family take...
# 3    Avengers: Infinity War As the Avengers and the...
# 4    The Invisible Man When Cecilia's abusive ex ta...
# ..                                                 ...
# 195  Thor Against his father Odin's will, The Might...
# 196  Alien: Covenant Bound for a remote planet on t...
# 197  The Mask When timid bank clerk Stanley Ipkiss ...
# 198  Mission: Impossible - Fallout When an IMF miss...
# 199  2001: A Space Odyssey Humanity finds a mysteri...
#
# [200 rows x 9 columns]

# %%
# now feed combined_features strings into CountVectorize object
cv = CountVectorizer()
count_matrix = cv.fit_transform(df["combined_features"])

# %%
count_matrix
# Out:
# <200x3223 sparse matrix of type '<class 'numpy.int64'>'
# 	with 8404 stored elements in Compressed Sparse Row format>

# %%
#print(cv.get_feature_names())
#print(count_matrix.toarray())

# %%
## get cosine similarity matrix
cosine_matrix = cosine_similarity(count_matrix)
cosine_matrix   # symmetrical matrix with diagonals = 1 (100 similar to each other)
# Out:
# array([[1.        , 0.44984383, 0.19820624, ..., 0.40729903, 0.41024184,
#         0.45457002],
#        [0.44984383, 1.        , 0.19813746, ..., 0.43294434, 0.40560277,
#         0.38781737],
#        [0.19820624, 0.19813746, 1.        , ..., 0.16145842, 0.1711842 ,
#         0.12427395],
#        ...,
#        [0.40729903, 0.43294434, 0.16145842, ..., 1.        , 0.29021087,
#         0.35113883],
#        [0.41024184, 0.40560277, 0.1711842 , ..., 0.29021087, 1.        ,
#         0.29783232],
#        [0.45457002, 0.38781737, 0.12427395, ..., 0.35113883, 0.29783232,
#         1.        ]])

# %%
# HELPER functions
def get_title_from_index(index, df):
    return df[df.index == index]["title"].values[0]
def get_index_from_title(title, df):
    # should iterate over all and see if coantains string
    title = title.title()
    return df[df.title == title].index.values[0]

print(get_title_from_index(4, df))
print(get_index_from_title("Thor", df))
print(get_index_from_title("Avatar", df))
# Out:
# The Invisible Man
# 195
# 126

# %% [markdown]
# Our next step is to get the title of the movie that the user currently likes. Then we will find the index of that movie. After that, we will access the row corresponding to this movie in the similarity matrix. Thus, we will get the similarity scores of all other movies from the current movie. Then we will enumerate through all the similarity scores of that movie to make a tuple of movie index and similarity score. This will convert a row of similarity scores like this- [1 0.5 0.2 0.9] to this- [(0, 1) (1, 0.5) (2, 0.2) (3, 0.9)] . Here, each item is in this form- (movie index, similarity score).

# %%
movie_user_likes = "Avatar"
movie_index = get_index_from_title(movie_user_likes, df)
similar_movies = list(enumerate(cosine_matrix[movie_index])) 
# accessing the row corresponding to given movie to find all the similarity scores
# for that movie and then enumerating over it
similar_movies  ## list of tuples (movie_index, similarity score to movie_user_likes)
# Out:
# [(0, 0.37181247169316833),
#  (1, 0.32448554053666706),
#  (2, 0.2105587219030789),
#  (3, 0.2856851356570029),
#  (4, 0.1287565506561512),
#  (5, 0.2586032735340944),
#  (6, 0.35349605916013666),
#  (7, 0.29821002598961344),
#  (8, 0.18832944617230332),
#  (9, 0.16081688022566923),
#  (10, 0.18761969359661412),
#  (11, 0.3062059890175074),
#  (12, 0.17868542247296582),
#  (13, 0.1939524551505708),
#  (14, 0.28661838988431687),
#  (15, 0.304275935729018),
#  (16, 0.3011721230063664),
#  (17, 0.2495492591311128),
#  (18, 0.22287124708010464),
#  (19, 0.27429019252949666),
#  (20, 0.17855051462249658),
#  (21, 0.25997347344787264),
#  (22, 0.33765162622095446),
#  (23, 0.24675590100659828),
#  (24, 0.36594210704893765),
#  (25, 0.3652311999283316),
#  (26, 0.2394201085048437),
#  (27, 0.161627045958809),
#  (28, 0.36883813286720696),
#  (127, 0.25788071477756375),
#  (44, 0.2573374643010911),
#  (68, 0.25628391481282986),
#  (173, 0.25507216374642366),
#  (84, 0.2549249642552304),
#  (183, 0.25486446230486953),
#  (182, 0.25477190211939277),
#  (148, 0.25384037467818854),
#  (123, 0.2533593918376833),
#  (131, 0.2526993478596345),
#  (91, 0.252310280118708),
#  (114, 0.25168100511526903),
#  (57, 0.2503915429180672),
#  (146, 0.2503242243141034),
#  (17, 0.2495492591311128),
#  (186, 0.24898915226512977),
#  (178, 0.24759378423606915),
#  (23, 0.24675590100659828),
#  (73, 0.2464135551870271),
#  (92, 0.24607943495851856),
#  (170, 0.24422500434906544),
#  (199, 0.24422500434906544),
#  (43, 0.24382992454708535),
#  (71, 0.24249160368647651),
#  (80, 0.2409900932515112),
#  (109, 0.24072846024282474),
#  (66, 0.24034556122481557),
#  (26, 0.2394201085048437),
#  (30, 0.23932498098297528),
#  (138, 0.2375422747394687),
#  (159, 0.23488808780588138),
#  (165, 0.23402293537155466),
#  (147, 0.23176179118107215),
#  (97, 0.22983614055242746),
#  (70, 0.2250967420452386),
#  (72, 0.22395700438234173),
#  (124, 0.22292541435446867),
#  (18, 0.22287124708010464),
#  (174, 0.22194838080923762),
#  (32, 0.2214546129433066),
#  (61, 0.21971768720102058),
#  (118, 0.2194469320923768),
#  (185, 0.21893716009046157),
#  (145, 0.2173399540921557),
#  (128, 0.21531408048872458),
#  (141, 0.21442250696755893),
#  (90, 0.21398266546446335),
#  (2, 0.2105587219030789),
#  (52, 0.2081453617075184),
#  (102, 0.20802038699693748),
#  (132, 0.20633868020813542),
#  (29, 0.20632815353005762),
#  (150, 0.2060104810498419),
#  (85, 0.20405773099713895),
#  (78, 0.20215947828770758),
#  (60, 0.2014148736276902),
#  (33, 0.20057388927143846),
#  (119, 0.19795189561622392),
#  (13, 0.1939524551505708),
#  (89, 0.19340379081188955),
#  (177, 0.18923271008903098),
#  (8, 0.18832944617230332),
#  (10, 0.18761969359661412),
#  (45, 0.18569533817705186),
#  (12, 0.17868542247296582),
#  (20, 0.17855051462249658),
#  (179, 0.175195446534857),
#  (121, 0.17400443716972247),
#  (99, 0.1650625228240461),
#  (184, 0.16413304107465318),
#  (129, 0.16208817969462155),
#  (27, 0.161627045958809),
#  (9, 0.16081688022566923),
#  (193, 0.16000261230887303),
#  (83, 0.1592324388246205),
#  (77, 0.15746933183579126),
#  (58, 0.15488061853247326),
#  (191, 0.14680505487867587),
#  (163, 0.1450036976414354),
#  (79, 0.1432670637653132),
#  (59, 0.14037248126871926),
#  (172, 0.14016830300607283),
#  (125, 0.13689641954834839),
#  (4, 0.1287565506561512),
#  (110, 0.12456821978060995),
#  (108, 0.07252642155445858)]

# %%
i = 0

for tup in sorted_similar_movies:
    index, score =  tup
    print(get_title_from_index(index, df))
    i+=1
    if i > 5:
        break
# Out:
# Avatar
# Brave
# Avengers: Age of Ultron
# Thor: Ragnarok
# The Hot Chick
# The Lord of the Rings: The Return of the King

# %%
### instead of this forloop, we would get entire rows by index and output that to HTML
